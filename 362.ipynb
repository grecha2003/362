# %%
# !pip install pyspark
# !pip install Faker
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=4ddbe4436eac2fa79f23befbcec1f00e31b29913f8a8aabfe8185ca2d43081b8
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1
# Collecting Faker
#   Downloading Faker-26.0.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: Faker
# Successfully installed Faker-26.0.0

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
from pyspark.sql import Row
from faker import Faker
import random

# %%
fake = Faker()
num_records = 1000
products = ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Printer']

# %%
    spark = SparkSession.builder \
        .appName("csv") \
        .getOrCreate()

# %%
 schema = StructType([
        StructField("Date", StringType(), True),
        StructField("UserID", IntegerType(), True),
        StructField("Product", StringType(), True),
        StructField("Quantity", IntegerType(), True),
        StructField("Price", FloatType(), True)
    ])

# %%
data = [Row(
        Date=str(fake.date_between(start_date='-1y', end_date='today')),
        UserID=fake.random_int(min=1, max=1000),
        Product=random.choice(products),
        Quantity=fake.random_int(min=1, max=5),
        Price=round(random.uniform(10, 1000), 2))
        for _ in range(num_records)]

# %%
    # Create DataFrame
    df = spark.createDataFrame(data, schema)

    # Show a few rows of the DataFrame
    df.show(truncate=False)

    # Write the DataFrame to a CSV file
    csv_file_path = "synthetic_data.csv"
    df.write.csv(csv_file_path, header=True, mode="overwrite")

    print(f"Data successfully written to {csv_file_path}")

    # Stop the Spark session
    spark.stop()
# Out:
# +----------+------+--------+--------+------+
# |Date      |UserID|Product |Quantity|Price |
# +----------+------+--------+--------+------+
# |2023-11-23|814   |Mouse   |1       |946.16|
# |2024-02-03|195   |Laptop  |5       |905.61|
# |2023-11-02|197   |Monitor |5       |657.19|
# |2023-07-26|412   |Monitor |2       |172.91|
# |2024-06-07|929   |Monitor |4       |901.81|
# |2023-12-17|35    |Printer |4       |276.04|
# |2023-08-08|1     |Keyboard|2       |384.5 |
# |2024-06-23|99    |Keyboard|3       |292.09|
# |2024-02-04|319   |Printer |2       |941.03|
# |2024-06-22|496   |Printer |3       |892.01|
# |2023-07-23|840   |Laptop  |1       |194.76|
# |2024-01-26|997   |Monitor |3       |876.58|
# |2023-11-13|666   |Printer |1       |133.64|
# |2024-07-18|865   |Printer |4       |320.13|
# |2024-06-29|653   |Mouse   |2       |104.73|
# |2023-11-21|537   |Mouse   |4       |187.54|
# |2023-11-20|395   |Keyboard|4       |429.08|
# |2023-09-13|33    |Monitor |5       |630.55|
# |2024-03-18|738   |Laptop  |5       |38.0  |
# |2024-02-25|631   |Monitor |1       |757.32|
# +----------+------+--------+--------+------+
# only showing top 20 rows
#
# Data successfully written to synthetic_data.csv
